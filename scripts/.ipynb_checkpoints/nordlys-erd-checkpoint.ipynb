# %%
import numpy as np
import pandas as pd
from pandas import DataFrame as df

# %%
# Query pre-porsessing
cols = ['MAP', 'RecipRank', 'R@5','R@10']
rows = ['MLM-tlc-sigir-index1', 'MLM-tlc-sigir-index2', 'MLM-tlc-sigir-index7',
        'MLM-tlc-jm-in2', 'MLM-tlc-jm-in7', 'MLM-tlc-dir-in2', 'MLM-tlc-dir-in7',
        'MLM-tc-jm-in7', 'MLM-tc-dir-in7',
        'LTR-tc-jm-in7-RF3]
res = [[0.7900, 0.8093, 0.9133, 0.9333],
       [0.7961, 0.8111, 0.9178, 0.9333],
       [0.7937, 0.8093, 0.9178, 0.9333],
       
       [0.7573, 0.7705, 0.8622, 0.8778],
       [0.7583, 0.7714, 0.8622, 0.9333],
       [0.7398, 0.6689, 0.8356, 0.8356],
       [0.7398, 0.7679, 0.8356, 0.8556],
       
       [0.7675, 0.7948, 0.8622, 0.9333],
       [0.7435, 0.7699, 0.8356, 0.8778]
       [0.8222, 0.7430, 0.9244, 0.9333]]
print "ERD-dev dataset"
my_df = df(res, index=rows, columns=cols)
my_df

# pt = PrettyTable(my_df)
# pt.set_cell_style(font_weight="bold", rows=[0, 1], cols=[4])
# pt
# my_df_proc = {'Y-erd': my_df.ix[:, [0, 1, 2, 3]], 'ERD': my_df.ix[:, [4, 5, 6, 7]]}
# print "CER step"
# pd.concat(my_df_proc, axis=1)
# Out:
# ERD-dev dataset
#                          MAP  RecipRank     R@5    R@10
# MLM-tlc-sigir-index1  0.7900     0.8093  0.9133  0.9333
# MLM-tlc-sigir-index2  0.7961     0.8111  0.9178  0.9333
# MLM-tlc-sigir-index7  0.7937     0.8093  0.9178  0.9333
# MLM-tlc-jm-in2        0.7573     0.7705  0.8622  0.8778
# MLM-tlc-jm-in7        0.7583     0.7714  0.8622  0.9333
# MLM-tlc-dir-in2       0.7398     0.6689  0.8356  0.8356
# MLM-tlc-dir-in7       0.7398     0.7679  0.8356  0.8556
# MLM-tc-jm-in7         0.7675     0.7948  0.8622  0.9333
# MLM-tc-dir-in7        0.7435     0.7699  0.8356  0.8778
# LTR-tc-jm-in7-RF3     0.8222     0.7430  0.9244  0.9333

# %%
# Commonness threshold for y-erd
# Query pre-porsessing
cols = ['MAP', 'R@5', ' ', ' ', 'MAP', 'R@5', ' ', ' ', 'MAP', 'R@5']
rows = ['MLM-c0.1', 'MLM-c0.2', 'MLM-c0.3', 'MLM-c0.4',  'MLM-c0.5', 'MLM-c0.6',  'MLM-c0.7', 'MLM-c0.8', 'MLM-c0.9']
res = [[0.7533, 0.8582, ' ', 'MLM-c0.01', 0.7338, 0.8642, ' ', 'MLM-c0.001', 0.6846, 0.8140],
       [0.7496, 0.8511, ' ', 'MLM-c0.02', 0.7446, 0.8640, ' ', 'MLM-c0.002', 0.6991, 0.8296],
       [0.7440, 0.8426, ' ', 'MLM-c0.03', 0.7510, 0.8641, ' ', 'MLM-c0.003', 0.7070, 0.8428],
       [0.7421, 0.8353, ' ', 'MLM-c0.04', 0.7542, 0.8641, ' ', 'MLM-c0.004', 0.7148, 0.8536],
       [0.7395, 0.8321, ' ', 'MLM-c0.05', 0.7561, 0.8645, ' ', 'MLM-c0.005', 0.7201, 0.8572],
       [0.7382, 0.8299, ' ', 'MLM-c0.06', 0.7561, 0.8630, ' ', 'MLM-c0.006', 0.7232, 0.8570],
       [0.7270, 0.8159, ' ', 'MLM-c0.07', 0.7555, 0.8630, ' ', 'MLM-c0.007', 0.7299, 0.8618],
       [0.7256, 0.8127, ' ', 'MLM-c0.08', 0.7538, 0.8606, ' ', 'MLM-c0.008', 0.7314, 0.8634],
       [0.7175, 0.8004, ' ', 'MLM-c0.09', 0.7533, 0.8582, ' ', 'MLM-c0.009', 0.7331, 0.8626]]
print "Results for Y-ERD dataset"
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
# Results for Y-ERD dataset
#              MAP     R@5                   MAP     R@5                    MAP  \
# MLM-c0.1  0.7533  0.8582     MLM-c0.01  0.7338  0.8642     MLM-c0.001  0.6846
# MLM-c0.2  0.7496  0.8511     MLM-c0.02  0.7446  0.8640     MLM-c0.002  0.6991
# MLM-c0.3  0.7440  0.8426     MLM-c0.03  0.7510  0.8641     MLM-c0.003  0.7070
# MLM-c0.4  0.7421  0.8353     MLM-c0.04  0.7542  0.8641     MLM-c0.004  0.7148
# MLM-c0.5  0.7395  0.8321     MLM-c0.05  0.7561  0.8645     MLM-c0.005  0.7201
# MLM-c0.6  0.7382  0.8299     MLM-c0.06  0.7561  0.8630     MLM-c0.006  0.7232
# MLM-c0.7  0.7270  0.8159     MLM-c0.07  0.7555  0.8630     MLM-c0.007  0.7299
# MLM-c0.8  0.7256  0.8127     MLM-c0.08  0.7538  0.8606     MLM-c0.008  0.7314
# MLM-c0.9  0.7175  0.8004     MLM-c0.09  0.7533  0.8582     MLM-c0.009  0.7331
#
#              R@5
# MLM-c0.1  0.8140
# MLM-c0.2  0.8296
# MLM-c0.3  0.8428
# MLM-c0.4  0.8536
# MLM-c0.5  0.8572
# MLM-c0.6  0.8570
# MLM-c0.7  0.8618
# ...

# %%
# Commonness threshold for y-erd
# Query pre-porsessing
cols = ['MAP', 'R@5']
rows = ['MLM-c0.05', 'MLM-c0.1']
res = [[0.7638, 0.8400],
       [0.7675, 0.8622]]
print "Results for ERD-dev dataset"
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
# Results for ERD-dev dataset
#               MAP     R@5
# MLM-c0.05  0.7638  0.8400
# MLM-c0.1   0.7675  0.8622

# %%
# Commonness threshold for y-erd
# Query pre-porsessing
cols = ['prec', 'Rec', 'F1']
rows = ['None', '0.1', '0.01', '0.001', '0.0001', '1e-05', '1e-06', '1e-07', '1e-08', '1e-09', '1e-10',
        '1e-11', '1e-12', '1e-13', '1e-14', '1e-15', '1e-16', '1e-17', '1e-18', '1e-19', '1e-20']
res = [[0.5212 , 0.6204 , 0.5665],
       [0.4086 , 0.03 , 0.0559],
       [0.6304 , 0.1144 , 0.1937],
       [0.7088 , 0.217 , 0.3323],
       [ 0.7286 , 0.2755 , 0.3998],
       [0.7216 , 0.311 , 0.4346],
       [0.69 , 0.3339 , 0.45],
       [0.6189 , 0.3575 , 0.4532],
       [0.5965 , 0.4025 , 0.4807],
       [0.5957 , 0.457 , 0.5172],
       [0.5902 , 0.4854 , 0.5327],
       [0.5839 , 0.5083 , 0.5435],
       [0.5751 , 0.5257 , 0.5493],
       [0.5616 , 0.547 , 0.5542],
       [0.554 , 0.5588 , 0.5564],
       [0.5499 , 0.5785 , 0.5638],
       [0.5463 , 0.5872 , 0.566],
       [0.543 , 0.5983 , 0.5693],
       [0.5411 , 0.603 , 0.5704],
       [0.5359 , 0.6062 , 0.5689],
       [0.5346 , 0.6101 , 0.5698]
       ]
print "Results for ERD-dev dataset"
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
# Results for ERD-dev dataset
#           prec     Rec      F1
# None    0.5212  0.6204  0.5665
# 0.1     0.4086  0.0300  0.0559
# 0.01    0.6304  0.1144  0.1937
# 0.001   0.7088  0.2170  0.3323
# 0.0001  0.7286  0.2755  0.3998
# 1e-05   0.7216  0.3110  0.4346
# 1e-06   0.6900  0.3339  0.4500
# 1e-07   0.6189  0.3575  0.4532
# 1e-08   0.5965  0.4025  0.4807
# 1e-09   0.5957  0.4570  0.5172
# 1e-10   0.5902  0.4854  0.5327
# 1e-11   0.5839  0.5083  0.5435
# 1e-12   0.5751  0.5257  0.5493
# 1e-13   0.5616  0.5470  0.5542
# 1e-14   0.5540  0.5588  0.5564
# 1e-15   0.5499  0.5785  0.5638
# 1e-16   0.5463  0.5872  0.5660
# 1e-17   0.5430  0.5983  0.5693
# 1e-18   0.5411  0.6030  0.5704
# 1e-19   0.5359  0.6062  0.5689
# 1e-20   0.5346  0.6101  0.5698

# %%
# Query pre-porsessing
cols = ['MAP', 'MRR', 'S@1', 'Prec', 'Rec', 'F1', 
        'MAP', 'MRR', 'S@1', 'Prec', 'Rec', 'F1',
        'MAP', 'MRR', 'S@1', 'Prec', 'Rec', 'F1']
rows = ['Cmn, Cmn-top(f)', 'Cmn, Cmn-top(uf)', 'TagMe', 
        'MLM, MLM-top', 'LTR, LTR-top']
# res: ysqle, y-erd, erd
res = [[0.4268, 0.4384, 0.4216, 0.4221, 0.4103, 0.4141, 
        0.7863, 0.8166, 0.7810, 0.7794, 0.7398, 0.7529, 
        0.7037, 0.7630, 0.7556, 0.7556, 0.6304, 0.6667],
       [0.6082, 0.6216, 0.5602, 0.5606, 0.5446, 0.5498, 
        0.6675, 0.6931, 0.6209, 0.6185, 0.5883, 0.5983, 
        0.5537, 0.6074, 0.5556, 0.5556, 0.4415, 0.4741],
       [0.6455, 0.6555, 0.5961, 0.4828, 0.7156, 0.5487, 
        0.7513, 0.7688, 0.7254, 0.5509, 0.7982, 0.6210,
        0.7026, 0.7889, 0.7556, 0.6333, 0.7304, 0.6407],
       [0.4068, 0.4152, 0.3761, 0.3761, 0.3674, 0.3703, 
        0.7533, 0.7689, 0.6867, 0.6867, 0.6485, 0.6611, 
        0.7675, 0.7948, 0.7333, 0.7333, 0.5970, 0.6370],
       ['-', '-', '-', '-', '-', '-',
        0.8654, 0.8769, 0.8481, 0.8481, 0.8038, 0.8183, 
        0.8200, 0.8370, 0.7556, 0.7556, 0.6452, 0.6778]]
my_df = df(res, index=rows, columns=cols)

eval_as = [my_df.ix[:, [0, 1, 2]], my_df.ix[:, [3, 4, 5]], my_df.ix[:, [6, 7, 8]], my_df.ix[:, [9, 10, 11]], my_df.ix[:, [12, 13, 14]], my_df.ix[:, [15, 16, 17]]]
my_df_sm = pd.concat(eval_as, axis=1, keys=["Eval as ER", "Eval as EL", "Eval as ER ", "Eval as EL ", "Eval as ER  ", "Eval as EL  "])

my_df_data = {'YSQLE': my_df_sm.ix[:, [0, 1, 2, 3, 4, 5]], 'Y-erd': my_df_sm.ix[:, [6, 7, 8, 9, 10, 11]], 'ERD': my_df_sm.ix[:, [12, 13, 14, 15, 16, 17]]}

# my_df_proc = {'YSQLE': my_df.ix[:, [0, 1, 2, 3, 4, 5]], 'Y-ERD': my_df.ix[:, [6, 7, 8, 9, 10, 11]], 'ERD': my_df.ix[:, [12, 13, 14, 15, 16, 17]]}
print "Entity ranking vs. entity linking"
pd.concat(my_df_data, axis=1)
# Out:
# Entity ranking vs. entity linking
#                           ERD                                               \
#                  Eval as ER                   Eval as EL
#                           MAP     MRR     S@1         Prec     Rec      F1
# Cmn, Cmn-top(f)        0.7037  0.7630  0.7556       0.7556  0.6304  0.6667
# Cmn, Cmn-top(uf)       0.5537  0.6074  0.5556       0.5556  0.4415  0.4741
# TagMe                  0.7026  0.7889  0.7556       0.6333  0.7304  0.6407
# MLM, MLM-top           0.7675  0.7948  0.7333       0.7333  0.5970  0.6370
# LTR, LTR-top           0.8200  0.8370  0.7556       0.7556  0.6452  0.6778
#
#                        Y-erd                                              \
#                  Eval as ER                  Eval as EL
#                          MAP     MRR     S@1        Prec     Rec      F1
# Cmn, Cmn-top(f)       0.7863  0.8166  0.7810      0.7794  0.7398  0.7529
# Cmn, Cmn-top(uf)      0.6675  0.6931  0.6209      0.6185  0.5883  0.5983
# ...

# %%
# Query pre-porsessing
cols = ['MAP', 'MRR', 'R@5', 'Prec', 'Rec', 'F1', 'Prec', 'Rec', 'F1',
        'MAP', 'MRR', 'R@5', 'Prec', 'Rec', 'F1', 'Prec', 'Rec', 'F1']
rows = ['Cmn(f)-top', 'TagMe(f)','MLM-top', 'LTR-top', 'LTR-LTR', 'MLM+c0', 'MLM+c0.1', 'MLM+c0.1-LTR']
# res: y-erd, erd
res = [[0.7863, 0.8166, 0.0000, 0.7794, 0.7398, 0.7529, 0.7022, 0.7, 0.7006, 
        0.7037, 0.7630, 0.0000, 0.7556, 0.6304, 0.6667, 0.6222, 0.5637, 0.5778],
       [0.8424, 0.8619, 0.8580, 0.8069, 0.8580, 0.8194, 0.6656, 0.663, 0.6637,
        0.7643, 0.8605, 0.7643, 0.8256, 0.7643, 0.7752, 0.7333, 0.6748, 0.6889],
       
       [0.7533, 0.7689, 0.8582, 0.6867, 0.6485, 0.6611, 0.6123, 0.6104, 0.6109,
        0.7675, 0.7948, 0.8622, 0.7333, 0.5970, 0.6370, 0.5778, 0.5193, 0.5333],
       [0.8654, 0.8769, 0.9026, 0.8481, 0.8038, 0.8183, 0.7619, 0.7597, 0.7604,
        0.8200, 0.8370, 0.9244, 0.7556, 0.6452, 0.6778, 0.6222, 0.5785, 0.5889],
       [ '-', '-', '-', '-', '-', '-', 0.7651, 0.7617, 0.7627,
         '-', '-', '-', '-', '-', '-', 0.6889, 0.6452, 0.6556],
       [0.8450, 0.8570, 0.9251, 0.7955, 0.7555, 0.7686, 0.7182, 0.7159, 0.7166,
        0.8626, 0.8893, 0.9356, 0.8444, 0.7259, 0.7630, 0.6889, 0.6481, 0.6593],
       [0.8520, 0.8217, 0.9062, 0.8217, 0.7780, 0.7924, 0.7365, 0.7342, 0.7349,
        0.8539, 0.8667, 0.9126, 0.8222, 0.7037, 0.7407, 0.6667, 0.6259, 0.637],
       [ '-', '-', '-', '-', '-', '-', 0.7771, 0.7744, 0.7752,
         '-', '-', '-', '-', '-', '-', 0.7111, 0.6704, 0.6815]]
my_df = df(res, index=rows, columns=cols)

eval_as = [my_df.ix[:, [0, 1, 2]], my_df.ix[:, [3, 4, 5]], my_df.ix[:, [6, 7, 8]], my_df.ix[:, [9, 10, 11]], my_df.ix[:, [12, 13, 14]], my_df.ix[:, [15, 16, 17]]]
my_df_sm = pd.concat(eval_as, axis=1, keys=["Eval as ER", "Eval as EL", "Eval as QU", "Eval as ER ", "Eval as EL ", "Eval as QU "])

my_df_data = {' Y-erd': my_df_sm.ix[:, [0, 1, 2, 3, 4, 5, 6, 7, 8]], 'ERD': my_df_sm.ix[:, [9, 10, 11, 12, 13, 14, 15, 16, 17]]}
pd.concat(my_df_data, axis=1)
# Out:
#                   Y-erd                                                        \
#              Eval as ER                 Eval as EL                 Eval as QU
#                     MAP     MRR     R@5       Prec     Rec      F1       Prec
# Cmn(f)-top       0.7863  0.8166       0     0.7794  0.7398  0.7529     0.7022
# TagMe(f)         0.8424  0.8619   0.858     0.8069   0.858  0.8194     0.6656
# MLM-top          0.7533  0.7689  0.8582     0.6867  0.6485  0.6611     0.6123
# LTR-top          0.8654  0.8769  0.9026     0.8481  0.8038  0.8183     0.7619
# LTR-LTR               -       -       -          -       -       -     0.7651
# MLM+c0            0.845   0.857  0.9251     0.7955  0.7555  0.7686     0.7182
# MLM+c0.1          0.852  0.8217  0.9062     0.8217   0.778  0.7924     0.7365
# MLM+c0.1-LTR          -       -       -          -       -       -     0.7771
#
#                                      ERD                                      \
# ...

# %%
# Query pre-porsessing
cols = ['MAP', 'MRR', 'S@1']
rows = ['TagMe-us', 'Tagme-FEL', 'Cmn-us', 'Cmn-FEL']
# res: ysqle, y-erd, erd
res = [[0.6455, 0.6555, 0.5961],
       [0.5458, 0.7043, 0.6682],
       [0.6082, 0.6216, 0.5602],
       [0.6418, 0.7798, 0.7336]]
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
#               MAP     MRR     S@1
# TagMe-us   0.6455  0.6555  0.5961
# Tagme-FEL  0.5458  0.7043  0.6682
# Cmn-us     0.6082  0.6216  0.5602
# Cmn-FEL    0.6418  0.7798  0.7336

# %%
# Query pre-porsessing
cols = ['MAP', 'MRR', 'R@5', 'Prec', 'Rec', 'F1', 
        'MAP', 'MRR', 'R@5', 'Prec', 'Rec', 'F1', 
        'MAP', 'MRR', 'R@5', 'Prec', 'Rec', 'F1']
rows = ['MLM', 'LTR', 'MLMg0', 'MLMg0.1']
# res: ysqle, y-erd, erd
res = [[0.4068, 0.3761, 0, 0.3761, 0.3674, 0.3703, 
        0.7533, 0.7689, 0.8582, 0.6867, 0.6485, 0.6611, 
        0.7675, 0.7948, 0.8622, 0.7333, 0.5970, 0.6370],
       ['-', '-', '-', '-', '-', '-',
        0.8654, 0.8769, 0.9026, 0.8481, 0.8038, 0.8183, 
        0.8200, 0.8370, 0.9244, 0.7556, 0.6452, 0.6778],
       [0, 0, 0, 0, 0, 0,
        0.8450, 0.8570, 0.9251, 0.7955, 0.7555, 0.7686,
        0.8626, 0.8893, 0.9356, 0.8444, 0.7259, 0.7630],
       ['-', '-', '-', '-', '-', '-',
        0.8520, 0.8217, 0.9062, 0.8217, 0.7780, 0.7924,
        0.8539, 0.8667, 0.9126, 0.8222, 0.7037, 0.7407]]
my_df = df(res, index=rows, columns=cols)

eval_as = [my_df.ix[:, [0, 1, 2]], my_df.ix[:, [3, 4, 5]], my_df.ix[:, [6, 7, 8]], my_df.ix[:, [9, 10, 11]], my_df.ix[:, [12, 13, 14]], my_df.ix[:, [15, 16, 17]]]
my_df_sm = pd.concat(eval_as, axis=1, keys=["Eval as ER", "Eval as EL", "Eval as ER ", "Eval as EL ", "Eval as ER  ", "Eval as EL  "])

my_df_data = {'YSQLE': my_df_sm.ix[:, [0, 1, 2, 3, 4, 5]], 'Y-erd': my_df_sm.ix[:, [6, 7, 8, 9, 10, 11]], 'ERD': my_df_sm.ix[:, [12, 13, 14, 15, 16, 17]]}

# my_df_proc = {'YSQLE': my_df.ix[:, [0, 1, 2, 3, 4, 5]], 'Y-ERD': my_df.ix[:, [6, 7, 8, 9, 10, 11]], 'ERD': my_df.ix[:, [12, 13, 14, 15, 16, 17]]}
print "Entity ranking vs. entity linking"
pd.concat(my_df_data, axis=1)
# Out:
# Entity ranking vs. entity linking
#                  ERD                                                    Y-erd  \
#         Eval as ER                   Eval as EL                   Eval as ER
#                  MAP     MRR     R@5         Prec     Rec      F1         MAP
# MLM           0.7675  0.7948  0.8622       0.7333  0.5970  0.6370      0.7533
# LTR           0.8200  0.8370  0.9244       0.7556  0.6452  0.6778      0.8654
# MLMg0         0.8626  0.8893  0.9356       0.8444  0.7259  0.7630      0.8450
# MLMg0.1       0.8539  0.8667  0.9126       0.8222  0.7037  0.7407      0.8520
#
#                                                          YSQLE              \
#                         Eval as EL                  Eval as ER
#             MRR     R@5        Prec     Rec      F1        MAP     MRR R@5
# MLM      0.7689  0.8582      0.6867  0.6485  0.6611     0.4068  0.3761   0
# LTR      0.8769  0.9026      0.8481  0.8038  0.8183          -       -   -
# ...

# %%
# Commonness threshold for y-erd
# Query pre-porsessing
cols = ['MAP', 'S@1', 'MRR', 'P', 'R', 'F']
rows = ['Commonness', 'MLM', 'MLM+c', 'LTR',  'TagMe']
res = [[0.6095, 0.5558, 0.6226, 0.5558, 0.5400, 0.5451],
       [0.3654, 0.2867, 0.3686, 0.3819, 0.3739, 0.3765],
       [0.6741, 0.6058, 0.6839, 0.6058, 0.5884, 0.5940],
       [0.4571, 0.4452, 0.4658, 0.4452, 0.4352, 0.4384],
       [0.6455, 0.5961, 0.6555, 0.4828, 0.7156, 0.5487]]
print "Results for Y-ERD dataset"
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
# Results for Y-ERD dataset
#                MAP     S@1     MRR       P       R       F
# Commonness  0.6095  0.5558  0.6226  0.5558  0.5400  0.5451
# MLM         0.3654  0.2867  0.3686  0.3819  0.3739  0.3765
# MLM+c       0.6741  0.6058  0.6839  0.6058  0.5884  0.5940
# LTR         0.4571  0.4452  0.4658  0.4452  0.4352  0.4384
# TagMe       0.6455  0.5961  0.6555  0.4828  0.7156  0.5487

# %%
cols = ['MAP', 'S@1', 'MRR', 'P', 'R', 'F']
rows = ['Commonness', 'MLM', 'MLM+c', 'LTR',  'TagMe', 'MLM(c0.1)', 'LTR(c0.1)']
res = [[0.6311, 0.5733, 0.6422, 0.5733, 0.5591, 0.5637],
       [0.3774, 0.2958, 0.3802, 0.3939, 0.3871, 0.3893],
       [0.6981, 0.6248, 0.7054, 0.6248, 0.6093, 0.6143],
       [0.4571, 0.4452, 0.4658, 0.4452, 0.4352, 0.4384],
       [0.6658, 0.6138, 0.6740, 0.4957, 0.7368, 0.5644],
       [0.4765, 0.3875, 0.4810, 0.4728, 0.4628, 0.4661],
       [0.4672, 0.4596, 0.4763, 0.4596, 0.4494, 0.4527]]
print "Results for YSQLE dataset"
my_df = df(res, index=rows, columns=cols)
my_df
# Out:
# Results for YSQLE dataset
#                MAP     S@1     MRR       P       R       F
# Commonness  0.6311  0.5733  0.6422  0.5733  0.5591  0.5637
# MLM         0.3774  0.2958  0.3802  0.3939  0.3871  0.3893
# MLM+c       0.6981  0.6248  0.7054  0.6248  0.6093  0.6143
# LTR         0.4571  0.4452  0.4658  0.4452  0.4352  0.4384
# TagMe       0.6658  0.6138  0.6740  0.4957  0.7368  0.5644
# MLM(c0.1)   0.4765  0.3875  0.4810  0.4728  0.4628  0.4661
# LTR(c0.1)   0.4672  0.4596  0.4763  0.4596  0.4494  0.4527

# %%
print "==================================================================================================="
print "========================================== New Results ============================================"
print "==================================================================================================="
# Out:
# ...
# ========================================== New Results ============================================
# ...

# %%
# Query pre-porsessing
cols = ['Prec', 'Rec', 'F1', 
        'Prec', 'Rec', 'F1', 
        'F1']
rows = ['TagMe(th0.1)', 'LTR-greedy', 'MLMg-greedy', 'LTR-greedyTagme(facc,th0.2)', 'LTR-greedyTagme(links,th0.2)']
# res: y-erd, erd-dev, erd-test
res = [[0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132,   0.6204],
       [0.8390, 0.8376, 0.8381,   0.7802, 0.7586, 0.7637,   0.5509],
       [0.6009, 0.5997, 0.6001,   0.6374, 0.6172, 0.6227,   '____'],  # top-0.4
       [0.8432, 0.8414, 0.842 ,   0.7582, 0.7366, 0.7418,   '____'],
       [0.8461, 0.8443, 0.8449,   0.7912, 0.7696, 0.7747,   '____']]
my_df = df(res, index=rows, columns=cols)

my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

print "Entity ranking vs. entity linking"
pd.concat(my_df_data, axis=1)
# Out:
# Entity ranking vs. entity linking
#                                Y-ERD                 ERD-dev                  \
#                                 Prec     Rec      F1    Prec     Rec      F1
# TagMe(th0.1)                  0.7415  0.7405  0.7408  0.8352  0.8062  0.8132
# LTR-greedy                    0.8390  0.8376  0.8381  0.7802  0.7586  0.7637
# MLMg-greedy                   0.6009  0.5997  0.6001  0.6374  0.6172  0.6227
# LTR-greedyTagme(facc,th0.2)   0.8432  0.8414  0.8420  0.7582  0.7366  0.7418
# LTR-greedyTagme(links,th0.2)  0.8461  0.8443  0.8449  0.7912  0.7696  0.7747
#
#                              ERD-test
#                                    F1
# TagMe(th0.1)                   0.6204
# LTR-greedy                     0.5509
# MLMg-greedy                      ____
# LTR-greedyTagme(facc,th0.2)      ____
# LTR-greedyTagme(links,th0.2)     ____

# %%
# Query pre-porsessing
cols = ['MAP', 'S@1', 'MRR', 'Prec', 'Rec', 'F1', 'Prec', 'Rec', 'F1']
rows = ['TagMe', 'TagMe(th0.1)']
# res: y-erd, erd-dev, erd-test
res = [[0.6665, 0.6144, 0.6748,  0.6860, 0.6846, 0.6850,   0.7072, 0.7189, 0.7097],  # TagMe
       [0.6766, 0.6322, 0.6863,  0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132]] # TagMe, th 0.1
my_df = df(res, index=rows, columns=cols)

my_df_data = {'  YSQLE': my_df.ix[:, [0, 1, 2]], ' Y-ERD': my_df.ix[:, [3, 4, 5]], 'ERD-dev': my_df.ix[:, [6, 7, 8]]}

print "TagMe results before and after filtering"
pd.concat(my_df_data, axis=1)
# Out:
# Entity ranking vs. entity linking
#                YSQLE                   Y-ERD                 ERD-dev          \
#                  MAP     S@1     MRR    Prec     Rec      F1    Prec     Rec
# TagMe         0.6665  0.6144  0.6748  0.6860  0.6846  0.6850  0.7072  0.7189
# TagMe(th0.1)  0.6766  0.6322  0.6863  0.7415  0.7405  0.7408  0.8352  0.8062
#
#
#                   F1
# TagMe         0.7097
# TagMe(th0.1)  0.8132

# %%
cols = ['MAP', 'Rprec', 'MRR', 'R@5', 'S@1',
        'MAP', 'Rprec', 'MRR', 'R@5', 'S@1']
rows = ['TagMe', 'TagMe(th0.1)', 'MLM', 'MLMc', 'MLMg', 'MLMcg', 'LTR', 'NLLR', 'LTR, NLLR', 'NLLRcg', '-']
res = [[0.8424, 0.8309, 0.8619, 0.8580, 0.8442,   0.7643, 0.7643, 0.8605, 0.7643, 0.8605],  # TagMe
       [0.8643, 0.8525, 0.8853, 0.8807, 0.8668,   0.7825, 0.7825, 0.8810, 0.7825, 0.8810],  # TagMe, th 0.1
       [0.5598, 0.4594, 0.5770, 0.6685, 0.4720,   0.5986, 0.5170, 0.6374, 0.6689, 0.5556],  # MLM
       [0.7533, 0.6744, 0.7689, 0.8582, 0.6867,   0.7675, 0.6881, 0.7948, 0.8622, 0.7333],  # MLMc
       [0.8450, 0.7810, 0.8570, 0.9251, 0.7955,   0.8626, 0.7948, 0.8893, 0.9356, 0.8444],  # MLMg
       [0.8520, 0.8102, 0.8630, 0.9062, 0.8217,   0.8539, 0.8126, 0.8667, 0.9126, 0.8222],  # MLMgc
       [0.8638, 0.8347, 0.8734, 0.9006, 0.8425,   0.8534, 0.7985, 0.8704, 0.9244, 0.8222],  # LTR(unnorm)
       [0.7526, 0.6733, 0.7682, 0.8573, 0.6856,   0.7675, 0.6881, 0.7948, 0.8622, 0.7333],  # NLLRc
       [0.8702, 0.8439, 0.8792, 0.9054, 0.8497,   0.8617, 0.8141, 0.8674, 0.9289, 0.8222],  # LTR, NLLR
       [0.8564, 0.8189, 0.8678, 0.9024, 0.8312,   0.8543, 0.7941, 0.8852, 0.9015, 0.8444],  # NLLRcg
       ['----', '----', '----', '----', '----',   0.8583, 0.8067, 0.8674, 0.9289, 0.8222],  # LTR, NLLR, positives
       ['----', '----', '----', '----', '----',   '----', '----', '----', '----', '----']]
print "Entity ranking results"
my_df = df(res, index=rows, columns=cols)
my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2, 3, 4]], 'ERD-dev': my_df.ix[:, [5, 6, 7, 8, 9]]}
pd.concat(my_df_data, axis=1)
# Out:
# Entity ranking results
#                Y-ERD                                 ERD-dev                  \
#                  MAP   Rprec     MRR     R@5     S@1     MAP   Rprec     MRR
# TagMe         0.8424  0.8309  0.8619   0.858  0.8442  0.7643  0.7643  0.8605
# TagMe(th0.1)  0.8643  0.8525  0.8853  0.8807  0.8668  0.7825  0.7825   0.881
# MLM           0.5598  0.4594   0.577  0.6685   0.472  0.5986   0.517  0.6374
# MLMc          0.7533  0.6744  0.7689  0.8582  0.6867  0.7675  0.6881  0.7948
# MLMg           0.845   0.781   0.857  0.9251  0.7955  0.8626  0.7948  0.8893
# MLMcg          0.852  0.8102   0.863  0.9062  0.8217  0.8539  0.8126  0.8667
# LTR           0.8638  0.8347  0.8734  0.9006  0.8425  0.8534  0.7985  0.8704
# NLLR          0.7526  0.6733  0.7682  0.8573  0.6856  0.7675  0.6881  0.7948
# LTR, NLLR     0.8702  0.8439  0.8792  0.9054  0.8497  0.8617  0.8141  0.8674
# NLLRcg        0.8564  0.8189  0.8678  0.9024  0.8312  0.8543  0.7941  0.8852
# ...

# %%
# Query pre-porsessing
cols = ['Prec', 'Rec', 'F1', 
        'Prec', 'Rec', 'F1',
        'F1']
rows = ['TagMe', 'TagMe(th0.1)', 'MLMgc-greedyTop', 'LTR-greedyTop', 
        'LTR-greedyTagme(graph,cmn)', 'LTR-greedyTagme(facc,score)', 'LTR-greedyTagme(facc_normalized,score)', 'LTR-greedyTagme(graph,score)', 'LTR-greedyTagme(graph_normalized,score)']
# res: y-erd, erd-dev, erd-test
res = [[0.6860, 0.6846, 0.6850,   0.7072, 0.7189, 0.7097,   '____'],  # TagMe
       [0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132,   0.6204],  # TagMe(th0.1)
       [0.6138, 0.6127, 0.6130,   0.6374, 0.6172, 0.6227,   '____'],  # MLMgc-greedyTop(th1e-5)
       [0.7740, 0.7730, 0.7733,   0.8132, 0.7916, 0.7967,   '____'],  # LTR-greedyTop(th0.4)
       [0.6188, 0.6179, 0.6182,   0.5714, 0.5714, 0.5714,   '____'],  # LTR-greedyTagme(graph,cmn,th0.2)
       [0.7723, 0.7709, 0.7713,   0.8022, 0.7806, 0.7857,   '____'],  # LTR-greedyTagme(facc,score,th0.2)
       [0.7752, 0.7738, 0.7743,   0.8242, 0.8026, 0.8077,   '____'],  # LTR-greedyTagme(facc_normalized,score,th0.2)
       [0.7677, 0.7661, 0.7666,   0.8022, 0.7806, 0.7857,   '____'],  # LTR-greedyTagme(graph,score,th0.2)
       [0.7756, 0.7743, 0.7747,   0.8242, 0.8026, 0.8077,   0.5828]]  # LTR-greedyTagme(graph_normalized,score,th0.2)
my_df = df(res, index=rows, columns=cols)

my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

print "Evaluation ERD, Greedy-TagMe"
pd.concat(my_df_data, axis=1)
# Out:
# Evaluation ERD, Greedy-TagMe
#                                           Y-ERD                 ERD-dev  \
#                                            Prec     Rec      F1    Prec
# TagMe                                    0.6860  0.6846  0.6850  0.7072
# TagMe(th0.1)                             0.7415  0.7405  0.7408  0.8352
# MLMgc-greedyTop                          0.6138  0.6127  0.6130  0.6374
# LTR-greedyTop                            0.7740  0.7730  0.7733  0.8132
# LTR-greedyTagme(graph,cmn)               0.6188  0.6179  0.6182  0.5714
# LTR-greedyTagme(facc,score)              0.7723  0.7709  0.7713  0.8022
# LTR-greedyTagme(facc_normalized,score)   0.7752  0.7738  0.7743  0.8242
# LTR-greedyTagme(graph,score)             0.7677  0.7661  0.7666  0.8022
# LTR-greedyTagme(graph_normalized,score)  0.7756  0.7743  0.7747  0.8242
#
#                                                         ERD-test
#                                             Rec      F1       F1
# ...

# %%
# Results for ISF-ML approaches
cols = ['Prec', 'Rec', 'F1', 
        'Prec', 'Rec', 'F1',
        'F1']
rows = ['TagMe', 'TagMe(th0.1)', 'MLMgc-greedyTop', 'LTR-greedyTop', 'LTR-greedyTagme',
        'LTR-CL1']
# res: y-erd, erd-dev, erd-test
res = [[0.6860, 0.6846, 0.6850,   0.7072, 0.7189, 0.7097,   '____'],  # TagMe
       [0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132,   0.6204],  # TagMe(th0.1)
       [0.6138, 0.6127, 0.6130,   0.6374, 0.6172, 0.6227,   '____'],  # MLMgc-greedyTop(th1e-5)
       [0.7740, 0.7730, 0.7733,   0.8132, 0.7916, 0.7967,   '____'],  # LTR-greedyTop(th0.4)
       [0.7756, 0.7743, 0.7747,   0.8242, 0.8026, 0.8077,   0.5828],  # LTR-greedyTagme(graph_normalized,score,th0.2)
       []]
my_df = df(res, index=rows, columns=cols)

my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

print "Evaluation ERD, ISF-LTR approach"
pd.concat(my_df_data, axis=1)
# Out:
# Evaluation ERD, ISF-LTR approach
#                   Y-ERD                 ERD-dev                 ERD-test
#                    Prec     Rec      F1    Prec     Rec      F1       F1
# TagMe            0.6860  0.6846  0.6850  0.7072  0.7189  0.7097     ____
# TagMe(th0.1)     0.7415  0.7405  0.7408  0.8352  0.8062  0.8132   0.6204
# MLMgc-greedyTop  0.6138  0.6127  0.6130  0.6374  0.6172  0.6227     ____
# LTR-greedyTop    0.7740  0.7730  0.7733  0.8132  0.7916  0.7967     ____
# LTR-greedyTagme  0.7756  0.7743  0.7747  0.8242  0.8026  0.8077   0.5828
# LTR-CL1             NaN     NaN     NaN     NaN     NaN     NaN     None

# %%
# Results for ISF-ML approaches
cols = ['Prec', 'Rec', 'F1', 
        'Prec', 'Rec', 'F1',
        'F1']
rows = ['TagMe', 'TagMe(th0.1)', 'LTR-greedy', #'MLMgc-greedyTop', 'LTR-greedyTop', 'LTR-greedyTagme',
        'Run5', 'Run6.1', 'Run7', 'Run8', 'Run9.1', 'Run10']
# res: y-erd, erd-dev, erd-test
res = [[0.6860, 0.6846, 0.6850,   0.7072, 0.7189, 0.7097,   '____'],  # TagMe
       [0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132,   0.6204],  # TagMe(th0.1)
#        [0.6138, 0.6127, 0.6130,   0.6374, 0.6172, 0.6227,   '____'],  # MLMgc-greedyTop(th1e-5)
#        [0.7740, 0.7730, 0.7733,   0.8132, 0.7916, 0.7967,   '____'],  # LTR-greedyTop(th0.4)
#        [0.7756, 0.7743, 0.7747,   0.8242, 0.8026, 0.8077,   0.5828],  # LTR-greedyTagme(graph_normalized,score,th0.2)
       [0.7650, 0.7672, 0.7654,   0.8407, 0.8172, 0.8231,   0.6853],    # LTR-greddy0.1-th0.3-c0.2-s0.8
#        ['____', '____', '____',   0.7692, 0.7696, 0.7601,   '____'],  # Run 1
#        ['____', '____', '____',   0.7692, 0.7806, 0.7637,   '____'],  # Run 2
#        ['____', '____', '____',   0.7491, 0.7696, 0.7454,   '____'],  # Run 3
#        ['____', '____', '____',   0.7784, 0.7696, 0.7656,   '____'],  # Run 4
       ['____', '____', '____',   0.7784, 0.7696, 0.7656,   '____'],  # Run 5
       ['____', '____', '____',   0.7619, 0.7586, 0.7509,   '____'],  # Run 6.1
#        ['____', '____', '____',   0.7363, 0.7256, 0.7234,   '____'],  # Run 6.2
#        ['____', '____', '____',   0.7344, 0.7366, 0.7253,   '____'],  # Run 6.3
       ['____', '____', '____',   0.7454, 0.7476, 0.7363,   '____'],  # Run 7
       ['____', '____', '____',   0.7399, 0.7476, 0.7326,   '____'],  # Run 8
       [0.7304, 0.7319, 0.7306,   0.7692, 0.7806, 0.7637,   0.5918]  # Run 9.1
#        ['____', '____', '____',   0.7802, 0.7916, 0.7747,   '____']  # Run 9.2
       ['____', '____', '____',   0.7802, 0.7696, 0.7674,   '____'],  # Run 10
#        ['____', '____', '____',   ,   '____'],  # Run
       ]
       
#        [0.6834, 0.6858, 0.6838,   0.5201, 0.5168, 0.5092,   '____'],  # Run 1
#        ['____', '____', '____',   0.5073, 0.5059, 0.4963,   '____'],  # Run 3
#        ['____', '____', '____',   0.5421, 0.5388, 0.5311,   '____'],  # Run 4
#        ['____', '____', '____',   0.5256, 0.5168, 0.5128,   '____'],  # Run 5
#        ['____', '____', '____',   0.4322, 0.4773, 0.4423,   '____'],  # Run 6
#        ['____', '____', '____',   0.5110, 0.4949, 0.4963,   '____'],  # Run 7
#        ['____', '____', '____',   0.5824, 0.5696, 0.5733,   '____'],  # Run 8
#        ['____', '____', '____',   0.5220, 0.5059, 0.5073,   '____'],  # Run 9
#        ['____', '____', '____',   0.5018, 0.5059, 0.4927,   '____'],  # Run 10
#        ]
my_df = df(res, index=rows, columns=cols)

my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

print "Evaluation ERD, ISF-LTR approach"
pd.concat(my_df_data, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-8b995c98af1c> in <module>()
#      24        [0.7304, 0.7319, 0.7306,   0.7692, 0.7806, 0.7637,   0.5918]  # Run 9.1
#      25 #        ['____', '____', '____',   0.7802, 0.7916, 0.7747,   '____']  # Run 9.2
# ---> 26        ['____', '____', '____',   0.7802, 0.7696, 0.7674,   '____'],  # Run 10
#      27 #        ['____', '____', '____',   ,   '____'],  # Run
#      28        ]
#
# TypeError: list indices must be integers, not tuple

# %%
# Table of ISF-ML settings
print "ISF-ML runs and settings"

cols = ['id', 'F1(ERD-dev)', '(#features) features', 'Aggregators', 'ML settings']
rows = ['Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run', 'Run']
# res: y-erd, erd-dev, erd-test
res = [[1, 0.7601, '(64) similar to SIGIR, execpt query_sim', 'similar to SIGIR', 'only pos inss, GBRT, t1000, d7'],  # Run 2
       [2, 0.7637, '(64) similar to SIGIR, execpt query_sim', 'similar to SIGIR', 'GBRT, t1000, d7'],  # Run 2
#        [3, 0.7454, '(23) cmn_nh, all_nh, jc_graph, len_ratio, connectedness, cmn, con_sim, mlm, score', 'min, mul, avg, wsum-men-pow', 'GBRT, t1000, d3'],  # Run 3
#        [4, 0.7656, '(13) cmn_nh, all_nh, jc_graph, co-occr-avg, len_ratio, cmn, con_sim, mlm, score', 'min, mul, avg, wsum-men-pow', 'GBRT, t1000, d3'],  # Run 4
       [5, 0.7656, '(13) cmn_nh, all_nh, jc_graph, jc_corpus, len_ratio, cmn, con_sim, mlm, score', 'mul, avg', 'GBRT, t1000, d3'],  # Run5
       [6.1, 0.7509, '(14) query_set_sim, cmn_nh, all_nh, jc_graph, jc_corpus, len_ratio, cmn, con_sim, mlm, score', 'mul, avg', 'GBRT, t1000, d3'],  # Run6
       [6.2, 0.7234, '(14) Run6.1' , 'Run 6.1', 'RF, t1000, m3'],  
       [6.3, 0.7253, '(14) Run6.1' , 'Run 6.1', 'GBRT, t1000, d2'],
       [7, 0.7363, '(15) P_s, cmn_nh, all_nh, jc_graph, jc_corpus, len_ratio, cmn, con_sim, mlm, score', 'mul, avg', 'GBRT, t1000, d3'],
       [8, 0.7363, '(16) H_s, P_s, cmn_nh, all_nh, jc_graph, jc_corpus, len_ratio, cmn, con_sim, mlm, score', 'mul, avg', 'GBRT, t1000, d3'],
       [9.1,  0.7637, '(70) all', 'all', 'GBRT, t1000, d7'],
       [9.2, 0.7747, '(70) all', 'all', 'GBRT, t1000, d8'],
       [9.3, 0.7527, '(70) all', 'all', 'GBRT, t1000, d3'],
       [10, 0.7674, '(21) all', 'mul, avg', 'GBRT, t1000, d3']
    ]
       
#        [1, 0.5092, '----', '(6) connectedness, co-occurrence, len_ratio_iset, commonness, mlm-tc, score', 'avg', 'cl, t1000, m2'],
#        [2, 0.5092, '----', '(6) connectedness, men_sim_avg, len_ratio_iset, commonness, mlm-tc, score', 'avg', 'cl, t1000, m2'],
#        [3, 0.4963, '----', '(6) connectedness, men_sim_avg, len_ratio_iset, commonness, mlm-tc, score', 'avg', 'cl, t1000, m1'],
#        [4, 0.5311, '----', '(6) connectedness, men_sim_avg, len_ratio_iset, commonness, mlm-tc, score', 'avg', 'cl, t1000, m3'],
#        [5, 0.5128, '----', '(6) connectedness, men_sim_avg, len_ratio_iset, commonness, mlm-tc, score', 'avg', 'cl, t1000, m4'],
#        [6, 0.4423, '----', '(5) connectedness, men_sim_avg, len_ratio_iset, commonness, mlm-tc', 'avg', 'cl, t1000, m3'],
#        [7, 0.4963, '----', '(82) all', 'all', 'cl, t1000, m6']
#        [8, 0.5733, '----', '(5) all', 'avg', 'rank, t1000, m3, th0.8']
#        [9, 0.5073, '----', '(5) similar to SIGIR', 'similar to SIGIR', 'rank, t1000, m3, th0.7']
#        [10, 0.4927, '----', '(5) similar to SIGIR', 'similar to SIGIR', 'rank, GBRT, t1000, m3, th0.7']
my_df = df(res, index=rows, columns=cols)
my_df

# my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

# pd.concat(my_df_data, axis=1)
# Out:
# ISF-ML runs and settings
#        id  F1(ERD-dev)                               (#features) features  \
# Run   1.0       0.7601            (64) similar to SIGIR, execpt query_sim
# Run   2.0       0.7637            (64) similar to SIGIR, execpt query_sim
# Run   5.0       0.7656  (13) cmn_nh, all_nh, jc_graph, jc_corpus, len_...
# Run   6.1       0.7509  (14) query_set_sim, cmn_nh, all_nh, jc_graph, ...
# Run   6.2       0.7234                                        (14) Run6.1
# Run   6.3       0.7253                                        (14) Run6.1
# Run   7.0       0.7363  (15) P_s, cmn_nh, all_nh, jc_graph, jc_corpus,...
# Run   8.0       0.7363  (16) H_s, P_s, cmn_nh, all_nh, jc_graph, jc_co...
# Run   9.1       0.7637                                           (70) all
# Run   9.2       0.7747                                           (70) all
# Run   9.3       0.7527                                           (70) all
# ...

# %%
# Results for ISF-ML approaches
cols = ['Prec', 'Rec', 'F1', 
        'Prec', 'Rec', 'F1',
        'F1']
rows = ['TagMe', 'TagMe(th0.1)', 'LTR-LTR', 'LTR-greedy']  #'MLMgc-greedyTop', 'LTR-greedyTop', 'LTR-greedyTagme',
#         'Run5', 'Run6.1', 'Run7', 'Run8', 'Run9.1', 'Run10']
# res: y-erd, erd-dev, erd-test
res = [[0.6860, 0.6846, 0.6850,   0.7072, 0.7189, 0.7097,   '____'],  # TagMe
       [0.7415, 0.7405, 0.7408,   0.8352, 0.8062, 0.8132,   0.6204],  # TagMe(th0.1)
#        [0.6138, 0.6127, 0.6130,   0.6374, 0.6172, 0.6227,   '____'],  # MLMgc-greedyTop(th1e-5)
#        [0.7740, 0.7730, 0.7733,   0.8132, 0.7916, 0.7967,   '____'],  # LTR-greedyTop(th0.4)
#        [0.7756, 0.7743, 0.7747,   0.8242, 0.8026, 0.8077,   0.5828],  # LTR-greedyTagme(graph_normalized,score,th0.2)
#        ['____', '____', '____',   0.7692, 0.7696, 0.7601,   '____'],  # Run 1
#        ['____', '____', '____',   0.7692, 0.7806, 0.7637,   '____'],  # Run 2
#        ['____', '____', '____',   0.7491, 0.7696, 0.7454,   '____'],  # Run 3
#        ['____', '____', '____',   0.7784, 0.7696, 0.7656,   '____'],  # Run 4
#        ['____', '____', '____',   0.7784, 0.7696, 0.7656,   '____'],  # Run 5
#        ['____', '____', '____',   0.7619, 0.7586, 0.7509,   '____'],  # Run 6.1
#        ['____', '____', '____',   0.7363, 0.7256, 0.7234,   '____'],  # Run 6.2
#        ['____', '____', '____',   0.7344, 0.7366, 0.7253,   '____'],  # Run 6.3
#        ['____', '____', '____',   0.7454, 0.7476, 0.7363,   '____'],  # Run 7
#        ['____', '____', '____',   0.7399, 0.7476, 0.7326,   '____'],  # Run 8
       [0.7304, 0.7319, 0.7306,   0.7692, 0.7806, 0.7637,   0.5918],  # Run 9.1
#        ['____', '____', '____',   0.7802, 0.7916, 0.7747,   '____']  # Run 9.2
#        ['____', '____', '____',   0.7802, 0.7696, 0.7674,   '____'],  # Run 10
       [0.7650, 0.7672, 0.7654,   0.8407, 0.8172, 0.8231,   0.6853]     # LTR-greddy0.1-th0.3-c0.2-s0.8
#        ['____', '____', '____',   ,   '____'],  # Run
       ]
       
#        [0.6834, 0.6858, 0.6838,   0.5201, 0.5168, 0.5092,   '____'],  # Run 1
#        ['____', '____', '____',   0.5073, 0.5059, 0.4963,   '____'],  # Run 3
#        ['____', '____', '____',   0.5421, 0.5388, 0.5311,   '____'],  # Run 4
#        ['____', '____', '____',   0.5256, 0.5168, 0.5128,   '____'],  # Run 5
#        ['____', '____', '____',   0.4322, 0.4773, 0.4423,   '____'],  # Run 6
#        ['____', '____', '____',   0.5110, 0.4949, 0.4963,   '____'],  # Run 7
#        ['____', '____', '____',   0.5824, 0.5696, 0.5733,   '____'],  # Run 8
#        ['____', '____', '____',   0.5220, 0.5059, 0.5073,   '____'],  # Run 9
#        ['____', '____', '____',   0.5018, 0.5059, 0.4927,   '____'],  # Run 10
#        ]
my_df = df(res, index=rows, columns=cols)

my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2]], 'ERD-dev': my_df.ix[:, [3, 4, 5]], 'ERD-test': my_df.ix[:, [6]]}

print "Evaluation ERD, ISF-LTR approach"
pd.concat(my_df_data, axis=1)
# Out:
# Evaluation ERD, ISF-LTR approach
#                Y-ERD                 ERD-dev                 ERD-test
#                 Prec     Rec      F1    Prec     Rec      F1       F1
# TagMe         0.6860  0.6846  0.6850  0.7072  0.7189  0.7097     ____
# TagMe(th0.1)  0.7415  0.7405  0.7408  0.8352  0.8062  0.8132   0.6204
# LTR-LTR       0.7304  0.7319  0.7306  0.7692  0.7806  0.7637   0.5918
# LTR-greedy    0.7650  0.7672  0.7654  0.8407  0.8172  0.8231   0.6853

# %%
print "WSDm results"
# Out:
# WSDm results

# %%
cols = ['MAP', 'Rprec', 'MRR', 'R@5', 'S@1', 'Time',
        'MAP', 'Rprec', 'MRR', 'R@5', 'S@1', 'Time']
rows = ['CMN', 'NLLRc', 'NLLRcg', 'LTR', '-',
        'Wiki-NLLRc', 'Wiki-LTR(0.02)', 'Wiki-LTR(0.008)']
res = [[0.7817, 0.7394, 0.8094, 0.8300, 0.7668, 0.3132,   0.6466, 0.6281, 0.7109, 0.6615, 0.6889, 0.0943],  # cmn, 0
       [0.7526, 0.6733, 0.7682, 0.8573, 0.6856, 0.0777,   0.7675, 0.6881, 0.7948, 0.8622, 0.7333, 0.1271],  # NLLRc
       [0.8564, 0.8189, 0.8678, 0.9024, 0.8312, 0.0757,   0.8543, 0.7941, 0.8852, 0.9015, 0.8444, 0.1321],  # NLLRcg
       [0.8690, 0.8403, 0.8784, 0.9054, 0.8481, 0.4741,   0.8617, 0.8185, 0.8667, 0.9111, 0.8222, 0.6596],  # LTR, NLLR
       ['----', '----', '----', '----', '----', '----',   '----', '----', '----', '----', '----', '----'],
       [0.7414, 0.6744, 0.7585, 0.8344, 0.6910, '----',   0.7835, 0.7215, 0.8130, 0.8659, 0.7556, '----'],  # NLLRc
       [0.8037, 0.7779, 0.8184, 0.8375, 0.7917, '----',   0.8142, 0.7778, 0.8370, 0.8481, 0.8000, '----'],  # LTR, 0.02]
       ['----', '----', '----', '----', '----', '----',   0.8248, 0.7733, 0.8365, 0.8622, 0.8000, '----']]  # LTR, 0.008
print "WSDM results"
my_df = df(res, index=rows, columns=cols)
my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2, 3, 4, 5]], 'ERD-dev': my_df.ix[:, [6, 7, 8, 9, 10, 11]]}
pd.concat(my_df_data, axis=1)
# Out:
# WSDM results
#                   Y-ERD                                         ERD-dev  \
#                     MAP   Rprec     MRR     R@5     S@1    Time     MAP
# CMN              0.7817  0.7394  0.8094    0.83  0.7668  0.3132  0.6466
# NLLRc            0.7526  0.6733  0.7682  0.8573  0.6856  0.0777  0.7675
# NLLRcg           0.8564  0.8189  0.8678  0.9024  0.8312  0.0757  0.8543
# LTR               0.869  0.8403  0.8784  0.9054  0.8481  0.4741  0.8617
# -                  ----    ----    ----    ----    ----    ----    ----
# Wiki-NLLRc       0.7414  0.6744  0.7585  0.8344   0.691    ----  0.7835
# Wiki-LTR(0.02)   0.8037  0.7779  0.8184  0.8375  0.7917    ----  0.8142
# Wiki-LTR(0.008)    ----    ----    ----    ----    ----    ----  0.8248
#
#
#                   Rprec     MRR     R@5     S@1    Time
# CMN              0.6281  0.7109  0.6615  0.6889  0.0943
# NLLRc            0.6881  0.7948  0.8622  0.7333  0.1271
# NLLRcg           0.7941  0.8852  0.9015  0.8444  0.1321
# ...

# %%
cols = ['Prec', 'Rec', 'F1', 'Time',
        'Prec', 'Rec', 'F1', 'Time',
        'F1', 'Time']
rows = ['TagMe', 'TagMe(th0.1)', 'Tagme-our',
        'LTR-LTR-k5', 'LTR-LTR-k10', 'LTR-LTR-k15', 'LTR-LTR-k20', 
        'LTR-greedy-sim-0.1', 'LTR-greedy-sim-0.2', 'LTR-greedy-sim-0.3', 'LTR-greedy-sim-0.4', 'LTR-greedy-sim-0.5', 'LTR-greedy-sim-0.6', 'LTR-greedy-sim-0.7', 'LTR-greedy-sim-0.8', 'LTR-greedy-sim-0.9', 
        'LTR-greedy-sim-0.2(jc)', 'LTR-greedy-0.3', 'LTR-greedy-0.3(jc)']  

# res: y-erd, erd-dev, erd-test
res = [[0.6860, 0.6846, 0.6850, '----',   0.7072, 0.7189, 0.7097, '----',   '----', '----'],  # TagMe
       [0.7415, 0.7405, 0.7408, '----',   0.8352, 0.8062, 0.8132, '----',   0.6204, '----'],  # TagMe(th0.1)
       [0.5842, 0.5837, 0.5838, 0.3459,   0.6154, 0.6026, 0.6062, 0.4487,   0.4012, 1.1748],  # TagMe-our
       [0.7311, 0.7344, 0.7318, 1.1994,   0.7802, 0.7696, 0.7674, 1.3174,   0.5723, 2.3677],  # LTR-LTR-k5
       [0.7117, 0.7174, 0.7131, 1.9270,   0.7692, 0.7586, 0.7564, 2.3633,   '----', '----'],  # LTR-LTR-k10
       [0.7196, 0.7234, 0.7205, 3.2689,   0.7582, 0.7476, 0.7454, 3.4891,   '----', '----'],  # LTR-LTR-k15
       [0.6665, 0.6715, 0.6678, 6.8603,   0.7692, 0.7586, 0.7564, 4.0958,   '----', '----'],  # LTR-LTR-k20
#        [0.6824, 0.6848, 0.6828, 0.7396,   0.7692, 0.7586, 0.7564, 0.7226,   0.5777, 2.3305],  # LTR-LTR-QD-2
       [0.7189, 0.7207, 0.7192, 0.5721,   0.7692, 0.7586, 0.7564, 0.9380,   0.5757, 1.5845],  # LTR-LTR-QD-3 
       [0.5167, 0.5165, 0.5164, 0.8731,   0.5000, 0.5055, 0.5018, 1.4291,   0.2495, 2.2220],  # LTR-LTR-QI-2
       [0.7250, 0.7273, 0.7253, '----',   0.7747, 0.7513, 0.7571, '----',   '----', '----'],  # LTR-greedy-qd-0.1
       [0.7763, 0.7778, 0.7763, 0.4694,   0.8407, 0.8172, 0.8231, 0.6811,   0.6808, 1.2189],  # LTR-greedy-qd-0.2
       [0.7823, 0.7832, 0.7822, '----',   0.8516, 0.8282, 0.8341, 0.6960,   0.6725, 1.1975],  # LTR-greedy-qd-0.3***
       [0.7798, 0.7801, 0.7794, '----',   0.8242, 0.8026, 0.8077, '----',   '----', '----'],  # LTR-greedy-qd-0.4
       [0.7588, 0.7590, 0.7584, '----',   0.7912, 0.7696, 0.7747, '----',   '----', '----'],  # LTR-greedy-qd-0.5
       [0.7329, 0.7330, 0.7326, '----',   0.7473, 0.7256, 0.7308, '----',   '----', '----'],  # LTR-greedy-qd-0.6
       [0.6947, 0.6947, 0.6944, '----',   0.6703, 0.6575, 0.6612, '----',   '----', '----'],  # LTR-greedy-qd-0.7
       [0.6447, 0.6449, 0.6447, '----',   0.6374, 0.6319, 0.6337, '----',   '----', '----'],  # LTR-greedy-qd-0.8
       [0.5738, 0.5738, 0.5738, '----',   0.6044, 0.5989, 0.6007, '----',   '----', '----'],  # LTR-greedy-qd-0.9
       [0.5728, 0.5733, 0.5726, '----',   0.7473, 0.7238, 0.7289, '----',   '----', '----'],  # LTR-greedy-qi-0.001
       [0.5932, 0.5951, 0.5934, '----',   0.7582, 0.7293, 0.7363, '----',   '----', '----'],  # LTR-greedy-qi-0.0001
       [0.6001, 0.6022, 0.6004, '----',   0.7582, 0.7293, 0.7363, '----',   '----', '----'],  # LTR-greedy-qi-1e-05
       [0.6009, 0.6031, 0.6012, '----',   0.7692, 0.7403, 0.7473, '----',   '----', '----'],  # LTR-greedy-qi-1e-06***
       [0.5992, 0.6014, 0.5995, '----',   0.7692, 0.7403, 0.7473, '----',   '----', '----'],  # LTR-greedy-qi-1e-07
       [0.6226, 0.6235, 0.6225, '----',   0.7692, 0.7403, 0.7473, 2.2480,   '----', '----'],  # LTR-greedy-qi-s0.3-r1e-06***
       [0.7790, 0.7774, 0.7779, '----',   0.8242, 0.8026, 0.8077]  # LTR-greedy-top-0.2
       [0.7759, 0.7774, 0.7759, '----',   0.8407, 0.8172, 0.8231, '----',   '----', '----'],  # LTLR-greedy-sim-0.2(jc)
       [0.7709, 0.7728, 0.7711, 0.4744,   0.8407, 0.8172, 0.8231, 0.6616,   0.6853, 1.2043],  # LTR-greedy-0.3
       [0.7836, 0.7853, 0.7837, 0.7178,   0.8736, 0.8502, 0.8560, 2.3021,   0.6753, 2.1813]]  # LTR-greedy-0.3-(jc-0.4)
#        [0.7877, 0.7886, 0.7876     0.6603] # LTR-greedy-0.4


# [0.4762, 0.4762, 0.4762, '----',   0.5055, 0.5055, 0.5055, '----',   '----', '----'],  # LTR-greedy-qi-0.1
#        [0.5031, 0.5035, 0.5032, '----',   0.4835, 0.4835, 0.4835, '----',   '----', '----'],  # LTR-greedy-qi-0.01
#        [0.5405, 0.5420, 0.5408, '----',   0.6044, 0.5883, 0.5916, '----',   '----', '----'],  # LTR-greedy-qi-0.001
#        [0.5630, 0.5649, 0.5631, '----',   0.6648, 0.6414, 0.6473, '----',   '----', '----'],  # LTR-greedy-qi-0.0001***
#        [0.5567, 0.5593, 0.5571, '----',   0.6374, 0.6194, 0.6216, '----',   '----', '----'],  # LTR-greedy-qi-1e-05
#        [0.5467, 0.5493, 0.5471, '----',   0.6154, 0.5974, 0.5996, '----',   '----', '----'],  # LTR-greedy-qi-1e-06
#        [0.6366, 0.6369, 0.6362, '----',   0.7692, 0.7403, 0.7473, 12.0658 (2.248),   '----', '----'],  # LTR-greedy-s0.3-r0.0001

my_df = df(res, index=rows, columns=cols)
my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2, 3]], 'ERD-dev': my_df.ix[:, [4, 5, 6, 7]], 'ERD-test': my_df.ix[:, [8, 9]]}

print "Evaluation ERD, ISF-LTR approach"
pd.concat(my_df_data, axis=1)
# Out:
# Evaluation ERD, ISF-LTR approach
#                          Y-ERD                         ERD-dev          \
#                           Prec     Rec      F1    Time    Prec     Rec
# TagMe                   0.6860  0.6846  0.6850    ----  0.7072  0.7189
# TagMe(th0.1)            0.7415  0.7405  0.7408    ----  0.8352  0.8062
# Tagme-our               0.5842  0.5837  0.5838  0.3459  0.6154  0.6026
# LTR-LTR-k5              0.7311  0.7344  0.7318  1.1994  0.7802  0.7696
# LTR-LTR-k10             0.7117  0.7174  0.7131   1.927  0.7692  0.7586
# LTR-LTR-k15             0.7196  0.7234  0.7205  3.2689  0.7582  0.7476
# LTR-LTR-k20             0.6665  0.6715  0.6678  6.8603  0.7692  0.7586
# LTR-greedy-sim-0.1      0.7250  0.7273  0.7253    ----  0.7747  0.7513
# LTR-greedy-sim-0.2      0.7763  0.7778  0.7763  0.4694  0.8407  0.8172
# LTR-greedy-sim-0.3      0.7823  0.7832  0.7822    ----  0.8516  0.8282
# LTR-greedy-sim-0.4      0.7798  0.7801  0.7794    ----  0.8242  0.8026
# ...

# %%
cols = ['Prec', 'Rec', 'F1', 'Time',
        'Prec', 'Rec', 'F1', 'Time',
        'F1', 'Time']
rows = ['TagMe', 'TagMe(th0.1)', 'Tagme-our',
        'LTR-LTR-k5', 'LTR-LTR-k10', 'LTR-LTR-k15', 'LTR-LTR-k20', 
        'LTR-greedy-sim-0.1', 'LTR-greedy-sim-0.2', 'LTR-greedy-sim-0.3', 'LTR-greedy-sim-0.4', 'LTR-greedy-sim-0.5', 'LTR-greedy-sim-0.6', 'LTR-greedy-sim-0.7', 'LTR-greedy-sim-0.8', 'LTR-greedy-sim-0.9', 
        'LTR-greedy-sim-0.2(jc)', 'LTR-greedy-0.3', 'LTR-greedy-0.3(jc)']  

# res: y-erd, erd-dev, erd-test
res = [[0.7759, 0.7774, 0.7759, '----',    0.8407, 0.8172, 0.8231, '----',   '----', '----'],  # LTR-greedy-0.2
       [0.7821, 0.7832, 0.7820, '----',    0.8516, 0.8282, 0.8341]
       [0.7836, 0.7845, 0.7834, '----',    0.8516, 0.8282, 0.8341],  # LTR-greedy-0.3
       [0.7877, 0.7886, 0.7876],  # LTR-greedy-0.31
       [0.7875, 0.7882, 0.7873],  # LTR-greedy-0.32
       [0.7842, 0.7849, 0.7840, '----',    0.8297, 0.8062, 0.8121],  # LTR-greedy-0.35 **
       [0.7807, 0.7809, 0.7802, '----',    0.8242, 0.8026, 0.8077],  # LTR-greedy-0.4
       

my_df = df(res, index=rows, columns=cols)
my_df_data = {' Y-ERD': my_df.ix[:, [0, 1, 2, 3]], 'ERD-dev': my_df.ix[:, [4, 5, 6, 7]], 'ERD-test': my_df.ix[:, [8, 9]]}

print "Evaluation ERD, ISF-LTR approach"
pd.concat(my_df_data, axis=1)
